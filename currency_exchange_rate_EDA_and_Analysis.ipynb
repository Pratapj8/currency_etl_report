# %% [markdown]
# # 🔍 1. Analyze Exchange Rate Trends
# - Study how rates change over time:
# - Plot rate changes for specific currency pairs.
# - Identify high/low rate periods.
# - Compute moving averages or volatility.
#
# - Example: How has the USD to AUD rate changed over the last month?

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## "Inserting data for the date only: 04/05/25"

# %%
df = pd.read_csv("/content/Conversion_rate_2025_05_08.csv")

# %%
df
# Out:
#       id base_currency target_currency        rate      date
# 0      1           USD             aud    1.554572  04/05/25
# 1      2           aud             USD    0.643264  04/05/25
# 2      3           USD             cad    1.381426  04/05/25
# 3      4           cad             USD    0.723890  04/05/25
# 4      5           USD             chf    0.825983  04/05/25
# ..   ...           ...             ...         ...       ...
# 865  866           zmw             INR    3.010884  04/05/25
# 866  867           INR             irr  496.166492  04/05/25
# 867  868           irr             INR    0.002015  04/05/25
# 868  869           INR             syp  154.515517  04/05/25
# 869  870           syp             INR    0.006472  04/05/25
#
# [870 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               870 non-null    int64
#  1   base_currency    870 non-null    object
#  2   target_currency  870 non-null    object
#  3   rate             870 non-null    float64
#  4   date             870 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 34.1+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# id                 0
# base_currency      0
# target_currency    0
# rate               0
# date               0
# dtype: int64

# %%
df.describe()
# Out:
#                id           rate
# count  870.000000     870.000000
# mean   435.500000     722.007196
# std    251.291663    5510.910320
# min      1.000000       0.000010
# 25%    218.250000       0.047997
# 50%    435.500000       1.000000
# 75%    652.750000      20.834460
# max    870.000000  101482.886800

# %% [markdown]
# # Key Insights from df.describe():
# - Count: 870 entries, meaning there are 870 rows in DataFrame.
#
# - Mean: The average rate is around 722.01.
#
# - Standard Deviation (std): A very high value of 5510.91, which indicates significant volatility or spread in the rate values.
#
# - Min: The smallest value is extremely small (0.000010), which suggests some very low rates.
#
# - Max: The highest value is very large (101482.89), which might indicate outliers or anomalies.

# %%
df[df["rate"] >= 722].sort_values(by="rate")
# Out:
#       id base_currency target_currency           rate      date
# 110  111           USD             aoa     917.839196  04/05/25
# 80    81           USD             clp     946.697572  04/05/25
# 400  401           EUR             aoa    1039.828167  04/05/25
# 656  657           INR             lbp    1063.368080  04/05/25
# 370  371           EUR             clp    1072.522077  04/05/25
# 112  113           USD             ars    1171.295391  04/05/25
# 170  171           USD             iqd    1310.000000  04/05/25
# 402  403           EUR             ars    1326.970938  04/05/25
# 20    21           USD             krw    1404.487108  04/05/25
# 236  237           USD             rwf    1415.302742  04/05/25
# 460  461           EUR             iqd    1484.110620  04/05/25
# 310  311           EUR             krw    1591.155903  04/05/25
# 218  219           USD             ngn    1596.200035  04/05/25
# 526  527           EUR             rwf    1603.409030  04/05/25
# ...

# %%
# Sum of rates >=722
(df["rate"] >= 722).sum()
# Out:
# np.int64(55)

# %%
# Filter out extreme low and high values
filtered_df = df[(df['rate'] > 0.01) & (df['rate'] < 1000)]
filtered_df
# Out:
#       id base_currency target_currency        rate      date
# 0      1           USD             aud    1.554572  04/05/25
# 1      2           aud             USD    0.643264  04/05/25
# 2      3           USD             cad    1.381426  04/05/25
# 3      4           cad             USD    0.723890  04/05/25
# 4      5           USD             chf    0.825983  04/05/25
# ..   ...           ...             ...         ...       ...
# 863  864           yer             INR    0.344123  04/05/25
# 864  865           INR             zmw    0.332128  04/05/25
# 865  866           zmw             INR    3.010884  04/05/25
# 866  867           INR             irr  496.166492  04/05/25
# 868  869           INR             syp  154.515517  04/05/25
#
# [693 rows x 5 columns]

# %% [markdown]
# ## 🔁 Currency Converter

# %%
def convert(amount, from_currency, to_currency, df):
    from_currency = from_currency.upper()
    to_currency = to_currency.upper()
    df = df.copy()
    df['base_currency'] = df['base_currency'].str.upper()
    df['target_currency'] = df['target_currency'].str.upper()

    row = df[(df['base_currency'] == from_currency) & (df['target_currency'] == to_currency)]

    if not row.empty:
        rate = row.iloc[0]['rate']
        return amount * rate
    else:
        return f"No rate found for {from_currency} to {to_currency}"

# %%
# Australian Dollar- AUD
convert(100, 'USD', 'AUD', df)
# Out:
# np.float64(155.457191)

# %%
# Bar Chart of Exchange Rates
import matplotlib.pyplot as plt

# Create a label combining base and target currencies for clarity
filtered_df['pair'] = filtered_df['base_currency'].str.upper() + ' → ' + filtered_df['target_currency'].str.upper()

# Sort for better visualization
plot_df = filtered_df.sort_values("rate", ascending=False)

# Plot
plt.figure(figsize=(12, 95))
plt.barh(plot_df['pair'], plot_df['rate'], color='skyblue')
plt.xlabel("Exchange Rate")
plt.title("Exchange Rates on 04/05/25")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Create the currency pair label
filtered_df['pair'] = filtered_df['base_currency'].str.upper() + ' → ' + filtered_df['target_currency'].str.upper()

# Sort and select top 20 highest rates
top20_df = filtered_df.sort_values("rate", ascending=False).head(20)

# Plot
plt.figure(figsize=(12, 8))
plt.barh(top20_df['pair'], top20_df['rate'], color='orange')
plt.xlabel("Exchange Rate")
plt.title("Top 20 Exchange Rates on 04/05/25")
plt.gca().invert_yaxis()  # Optional: highest rate on top
plt.tight_layout()
plt.show()

# %%
target_currency.unique()
# Out:
# array(['clp', 'aoa', 'sdg', 'xof', 'xaf', 'sos', 'kzt', 'crc', 'irr',
#        'kmf', 'amd', 'huf'], dtype=object)

# %%
currencies = {
    'clp': 'Chilean Peso',
    'aoa': 'Angolan Kwanza',
    'sdg': 'Sudanese Pound',
    'xof': 'West African CFA Franc',
    'xaf': 'Central African CFA Franc',
    'sos': 'Somali Shilling',
    'kzt': 'Kazakhstani Tenge',
    'crc': 'Costa Rican Colón',
    'irr': 'Iranian Rial',
    'kmf': 'Comorian Franc',
    'amd': 'Armenian Dram',
    'huf': 'Hungarian Forint'
}
# Out:
# {'clp': 'Chilean Peso',
#  'aoa': 'Angolan Kwanza',
#  'sdg': 'Sudanese Pound',
#  'xof': 'West African CFA Franc',
#  'xaf': 'Central African CFA Franc',
#  'sos': 'Somali Shilling',
#  'kzt': 'Kazakhstani Tenge',
#  'crc': 'Costa Rican Colón',
#  'irr': 'Iranian Rial',
#  'kmf': 'Comorian Franc',
#  'amd': 'Armenian Dram',
#  'huf': 'Hungarian Forint'}

# %%
import matplotlib.pyplot as plt

# Your currency name mapping
currencies = {
    'clp': 'Chilean Peso',
    'aoa': 'Angolan Kwanza',
    'sdg': 'Sudanese Pound',
    'xof': 'West African CFA Franc',
    'xaf': 'Central African CFA Franc',
    'sos': 'Somali Shilling',
    'kzt': 'Kazakhstani Tenge',
    'crc': 'Costa Rican Colón',
    'irr': 'Iranian Rial',
    'kmf': 'Comorian Franc',
    'amd': 'Armenian Dram',
    'huf': 'Hungarian Forint'
}

# Normalize currency codes to lowercase for matching
filtered_df['base_currency'] = filtered_df['base_currency'].str.lower()
filtered_df['target_currency'] = filtered_df['target_currency'].str.lower()

# Add readable currency names (fall back to code if not in dict)
def get_currency_name(code):
    return currencies.get(code, code.upper())

filtered_df['pair'] = (
    filtered_df['base_currency'].apply(get_currency_name) +
    ' → ' +
    filtered_df['target_currency'].apply(get_currency_name)
)

# Sort and select top 20
top20_df = filtered_df.sort_values("rate", ascending=False).head(20)

# Plot
plt.figure(figsize=(12, 8))
plt.barh(top20_df['pair'], top20_df['rate'], color='orange')
plt.xlabel("Exchange Rate")
plt.title("Top 20 Exchange Rates on 04/05/25 (with Full Currency Names)")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
top20_df
# Out:
#       id base_currency target_currency        rate      date       pair
# 80    81           USD             clp  946.697572  04/05/25  USD → CLP
# 110  111           USD             aoa  917.839196  04/05/25  USD → AOA
# 532  533           EUR             sdg  680.167704  04/05/25  EUR → SDG
# 388  389           EUR             xof  655.152520  04/05/25  EUR → XOF
# 386  387           EUR             xaf  655.152520  04/05/25  EUR → XAF
# 534  535           EUR             sos  647.706663  04/05/25  EUR → SOS
# 242  243           USD             sdg  600.372829  04/05/25  USD → SDG
# 380  381           EUR             kzt  583.846776  04/05/25  EUR → KZT
# 96    97           USD             xaf  578.292339  04/05/25  USD → XAF
# 98    99           USD             xof  578.292339  04/05/25  USD → XOF
# 428  429           EUR             crc  572.885745  04/05/25  EUR → CRC
# 244  245           USD             sos  571.720003  04/05/25  USD → SOS
# ...

# %% [markdown]
# #  Identify Most and Least Valuable Currency Pairs

# %%
# Get row with max and min rates
max_row = filtered_df.loc[filtered_df['rate'].idxmax()]
min_row = filtered_df.loc[filtered_df['rate'].idxmin()]

def describe_pair(row):
    base = currencies.get(row['base_currency'], row['base_currency'].upper())
    target = currencies.get(row['target_currency'], row['target_currency'].upper())
    return f"{base} → {target} = {row['rate']}"

print("🔺 Highest Exchange Rate:")
print(describe_pair(max_row))

print("\n🔻 Lowest Exchange Rate:")
print(describe_pair(min_row))
# Out:
# 🔺 Highest Exchange Rate:
# USD → Chilean Peso = 946.6975722
#
# 🔻 Lowest Exchange Rate:
# KGS → EUR = 0.01009358

# %%
currencies
# Out:
# {'clp': 'Chilean Peso',
#  'aoa': 'Angolan Kwanza',
#  'sdg': 'Sudanese Pound',
#  'xof': 'West African CFA Franc',
#  'xaf': 'Central African CFA Franc',
#  'sos': 'Somali Shilling',
#  'kzt': 'Kazakhstani Tenge',
#  'crc': 'Costa Rican Colón',
#  'irr': 'Iranian Rial',
#  'kmf': 'Comorian Franc',
#  'amd': 'Armenian Dram',
#  'huf': 'Hungarian Forint'}

# %%
top_strength_df
# Out:
#     currency  average_rate
# 64       kwd     93.570928
# 126      usd     92.194166
# 39       eur     88.453284
# 13       bhd     76.438223
# 90       omr     74.667927
# 57       jod     40.490605
# 41       gbp     38.172106
# 44       gip     38.160885
# 24       chf     34.755303
# 91       pab     28.707293

# %%
strength_df_cur = strength_df.head(10)
strength_df_cur
# Out:
#     currency  average_rate
# 64       kwd     93.570928
# 126      usd     92.194166
# 39       eur     88.453284
# 13       bhd     76.438223
# 90       omr     74.667927
# 57       jod     40.490605
# 41       gbp     38.172106
# 44       gip     38.160885
# 24       chf     34.755303
# 91       pab     28.707293

# %%
strength_df_cur['currency'].unique()
# Out:
# array(['kwd', 'usd', 'eur', 'bhd', 'omr', 'jod', 'gbp', 'gip', 'chf',
#        'pab'], dtype=object)

# %%
unique_currencies = {
    'kwd': 'Kuwaiti Dinar',
    'usd': 'United States Dollar',
    'eur': 'Euro',
    'bhd': 'Bahraini Dinar',
    'omr': 'Omani Rial',
    'jod': 'Jordanian Dinar',
    'gbp': 'British Pound Sterling',
    'gip': 'Gibraltar Pound',
    'chf': 'Swiss Franc',
    'pab': 'Panamanian Balboa'
}

# %%
strength_df.head(10)
# Out:
#     currency  average_rate
# 64       kwd     93.570928
# 126      usd     92.194166
# 39       eur     88.453284
# 13       bhd     76.438223
# 90       omr     74.667927
# 57       jod     40.490605
# 41       gbp     38.172106
# 44       gip     38.160885
# 24       chf     34.755303
# 91       pab     28.707293

# %% [markdown]
# # Calculate Currency Strength (Average Rate)

# %%
import matplotlib.pyplot as plt

# Plot the top 10 strongest currencies based on average exchange rate
top_strength_df = strength_df.head(10)

plt.figure(figsize=(12, 8))
plt.barh(top_strength_df['currency'].str.upper(), top_strength_df['average_rate'], color='green')
plt.xlabel("Average Exchange Rate")
plt.title("Top 10 Strongest Currencies on 04/05/25")
plt.gca().invert_yaxis()  # Optional: Strongest currency at the top
plt.tight_layout()
plt.show()

# %%
strength_df.head(10)
# Out:
#     currency  average_rate
# 64       kwd     93.570928
# 126      usd     92.194166
# 39       eur     88.453284
# 13       bhd     76.438223
# 90       omr     74.667927
# 57       jod     40.490605
# 41       gbp     38.172106
# 44       gip     38.160885
# 24       chf     34.755303
# 91       pab     28.707293

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data for currencies and their average rates
data = {
    'currency': ['kwd', 'usd', 'eur', 'bhd', 'omr', 'jod', 'gbp', 'gip', 'chf', 'pab'],
    'average_rate': [93.570928, 92.194166, 88.453284, 76.438223, 74.667927,
                     40.490605, 38.172106, 38.160885, 34.755303, 28.707293]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Mapping for long-form currency names
currency_map = {
    'kwd': 'Kuwaiti Dinar', 'usd': 'United States Dollar', 'eur': 'Euro',
    'bhd': 'Bahraini Dinar', 'omr': 'Omani Rial', 'jod': 'Jordanian Dinar',
    'gbp': 'British Pound Sterling', 'gip': 'Gibraltar Pound', 'chf': 'Swiss Franc',
    'pab': 'Panamanian Balboa'
}

# Add a new column with the long-form names
df['currency_name'] = df['currency'].map(currency_map)

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(df['currency_name'], df['average_rate'], color='skyblue')

# Add titles and labels
plt.title('Average Exchange Rates by Currency', fontsize=14)
plt.xlabel('Currency', fontsize=12)
plt.ylabel('Average Rate', fontsize=12)
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Detect Arbitrage Opportunities
#
# - Arbitrage occurs when you can exploit price differences in different currency pairs to make a profit. If there’s a discrepancy in the exchange rates between direct and indirect conversions, it could signal an opportunity.
#
# - We can detect arbitrage by comparing direct exchange rates with indirect exchange rates. For example:
#
# - Convert USD → EUR using the direct rate.
#
# - Then, convert USD → GBP → EUR by going through GBP.
#
# - If the indirect rate differs significantly from the direct rate, there may be an arbitrage opportunity.

# %%
# Step 1: Get direct USD → EUR rate
usd_eur_direct = filtered_df[(filtered_df['base_currency'] == 'usd') & (filtered_df['target_currency'] == 'eur')]['rate'].iloc[0]

# Step 2: Get indirect USD → GBP and GBP → EUR rates
usd_gbp = filtered_df[(filtered_df['base_currency'] == 'usd') & (filtered_df['target_currency'] == 'gbp')]['rate'].iloc[0]
gbp_eur = filtered_df[(filtered_df['base_currency'] == 'gbp') & (filtered_df['target_currency'] == 'eur')]['rate'].iloc[0]

# Calculate indirect rate: USD → GBP → EUR
usd_eur_indirect = usd_gbp * gbp_eur

# Step 3: Compare direct and indirect rates
arbitrage_opportunity = abs(usd_eur_direct - usd_eur_indirect)

print(f"Direct USD → EUR Rate: {usd_eur_direct}")
print(f"Indirect USD → EUR Rate via GBP: {usd_eur_indirect}")
print(f"Difference (Potential Arbitrage Opportunity): {arbitrage_opportunity}")
# Out:
# Direct USD → EUR Rate: 0.88268353
# Indirect USD → EUR Rate via GBP: 0.8826835235265046
# Difference (Potential Arbitrage Opportunity): 6.473495406389418e-09

# %% [markdown]
# # Interpretation:
# ### - The difference between the direct rate and the indirect rate is extremely small (6.47349), which is essentially zero within the precision of most financial data.
#
# # Conclusion:
# ### - There seems to be no significant arbitrage opportunity for the USD → EUR pair via GBP on the given day, as the difference is too small to take advantage of.

# %% [markdown]
# # An arbitrage opportunity is like a chance to make money by taking advantage of price differences.
# - Imagine you're shopping in two different stores, and one store is selling a product for less than the other. You can buy it cheap from the first store and sell it for a higher price at the second store, making a profit without any risk.
